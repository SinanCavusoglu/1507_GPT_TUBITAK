# %% [markdown]
# ## [Extract Text](https://towardsdatascience.com/extracting-text-from-pdf-files-with-python-a-comprehensive-guide-9fc4003d517)
#
# ## [Language Detect](https://github.com/zafercavdar/fasttext-langdetect)

# %%
from io import StringIO

import os
import re
#import PyPDF2
from pdfminer.high_level import extract_pages, extract_text
from pdfminer.layout import LTTextContainer, LTChar, LTRect, LTFigure, LAParams
#from ftlangdetect import detect
import pycld2 as cld2

# %%
def collect_clear_text(text_list):
    text_list = [re.sub(r'\s+', ' ', text_.strip()).strip() for text_ in text_list]
    text = ' '.join(text_list)
    return text.strip()

def contents_references_rmv(text_per_page: dict,pages = 30, char_num = 1500, years_num = 6):
    def less_char_drop(text,char_num):
        if len(text) < char_num: return True
    def dot_drop(text):
        if (len(text) > char_num) and ((text.count(".") > 40) or (text.count("…")> 10) or (text.count("_")> 10) or (text.count("-")>10)) : return True
    def referencesYear_drop(text):
        year_list = list(range(1900,2025))
        year_count = 0
        for year in year_list:
            if str(year) in text:
                year_count += 1
        if year_count > years_num: return True
    total_pages = len(text_per_page)
    obs_numbers = list(range(0,pages)) + list(range(total_pages-pages,total_pages))
    for page_num in obs_numbers:
        page_word = f'Page_{page_num}'
        if page_num < pages:
            try:
                if (less_char_drop(text_per_page[page_word],char_num)) or (dot_drop(text_per_page[page_word]))  : del text_per_page[page_word]   
            except KeyError:
                continue
        else:
            if (less_char_drop(text_per_page[page_word],char_num)) or (referencesYear_drop(text_per_page[page_word]))  : del text_per_page[page_word]
    return text_per_page
    
def remove_eng(text_per_page: dict):
    dict_keys = list(text_per_page.keys())
    for keys in dict_keys: 
        text = text_per_page[keys]
        try:
            isReliable, textBytesFound, details = cld2.detect(text)
        except Exception as e:
            del text_per_page[keys]
            continue    
        lang = details[0][1]
        score = details[0][2]
        #print(keys, lang)
        if (lang == 'tr') and (score < 0.69):
            del text_per_page[keys]
        elif lang != "tr":
            del text_per_page[keys]
    return text_per_page

# %%
pdf_listDir = os.listdir("YOK_download_pdf")
for pdf in pdf_listDir:
    text_per_page = {}
    pdf_path = f'YOK_download_pdf/{pdf}'
    try:
        for pagenum, page in enumerate(extract_pages(pdf_path, laparams=LAParams(line_margin=2))):
            page_text = []
            page_elements = [(element.y1, element) for element in page._objs]
            page_elements.sort(key=lambda a: a[0], reverse=True)
            for i, component in enumerate(page_elements):
                element = component[1]
                if isinstance(element, LTTextContainer):
                    line_text = element.get_text()
                    page_text.append(line_text)
            dctkey = 'Page_' + str(pagenum)
            text_per_page[dctkey] = collect_clear_text(page_text)
    except TypeError as e:
        print(f"Error processing {pdf}: {e}")
        os.remove(pdf_path)
        continue
    except ValueError as e:
        print(f"Error processing {pdf}: {e}")
        os.remove(pdf_path)
        continue
    except Exception as e:
        print(f"Error processing {pdf}: {e}")
        os.remove(pdf_path)
        continue
    rawTotal = len(text_per_page)
    text_per_page = contents_references_rmv(text_per_page=text_per_page)
    text_per_page = remove_eng(text_per_page=text_per_page)
    """
    try:
        text_per_page = remove_eng(text_per_page=text_per_page)
    except Exception as e:
        print(f"Error in remove_eng for {pdf}: {e}")
        os.remove(pdf_path)
        continue
    """
    clearedTotal = len(text_per_page)
    if clearedTotal < 8:
        print("Bozuk pdf:", pdf)
    print("PDF:", pdf, "Raw_Pages:", rawTotal, "Cleared_Total:", clearedTotal)
    with open(f"YOK_TEXT/{pdf.split('.')[0]}.txt" , 'w+', encoding="utf-8") as txt:
        for text in text_per_page.values():
            txt.write(text)
            txt.write('\n')
    os.rename( f"YOK_download_pdf/{pdf}", f"YOK_download_pdf_fin/finished_{pdf}")
# Out:
# Error processing 194244.pdf: Unexpected EOF
# PDF: 194245.pdf Raw_Pages: 181 Cleared_Total: 132
# PDF: 194246.pdf Raw_Pages: 96 Cleared_Total: 63
# PDF: 194265.pdf Raw_Pages: 79 Cleared_Total: 39
# PDF: 194266.pdf Raw_Pages: 80 Cleared_Total: 46
# PDF: 194267.pdf Raw_Pages: 77 Cleared_Total: 38
# PDF: 194268.pdf Raw_Pages: 54 Cleared_Total: 28
# PDF: 194269.pdf Raw_Pages: 91 Cleared_Total: 58
# PDF: 194270.pdf Raw_Pages: 87 Cleared_Total: 55
# PDF: 194271.pdf Raw_Pages: 71 Cleared_Total: 49
# PDF: 194272.pdf Raw_Pages: 81 Cleared_Total: 47
# PDF: 194283.pdf Raw_Pages: 71 Cleared_Total: 32
# PDF: 194284.pdf Raw_Pages: 65 Cleared_Total: 9
# PDF: 194292.pdf Raw_Pages: 77 Cleared_Total: 53
# PDF: 194293.pdf Raw_Pages: 75 Cleared_Total: 47
# PDF: 194295.pdf Raw_Pages: 80 Cleared_Total: 35
# PDF: 194501.pdf Raw_Pages: 96 Cleared_Total: 48
# PDF: 194502.pdf Raw_Pages: 222 Cleared_Total: 176
# PDF: 194504.pdf Raw_Pages: 63 Cleared_Total: 30
# PDF: 194505.pdf Raw_Pages: 79 Cleared_Total: 44
# PDF: 194506.pdf Raw_Pages: 102 Cleared_Total: 70
# PDF: 194507.pdf Raw_Pages: 51 Cleared_Total: 20
# PDF: 194508.pdf Raw_Pages: 61 Cleared_Total: 28
# PDF: 194509.pdf Raw_Pages: 69 Cleared_Total: 32
# PDF: 194511.pdf Raw_Pages: 62 Cleared_Total: 29
# PDF: 194512.pdf Raw_Pages: 136 Cleared_Total: 99
# Bozuk pdf: 194513.pdf
# PDF: 194513.pdf Raw_Pages: 110 Cleared_Total: 0
# PDF: 194514.pdf Raw_Pages: 88 Cleared_Total: 44
# PDF: 194515.pdf Raw_Pages: 108 Cleared_Total: 72
# PDF: 194516.pdf Raw_Pages: 139 Cleared_Total: 100
# PDF: 194526.pdf Raw_Pages: 65 Cleared_Total: 21
# PDF: 194527.pdf Raw_Pages: 57 Cleared_Total: 19
# PDF: 194528.pdf Raw_Pages: 99 Cleared_Total: 61
# PDF: 194529.pdf Raw_Pages: 47 Cleared_Total: 16
# PDF: 194530.pdf Raw_Pages: 85 Cleared_Total: 43
# PDF: 194531.pdf Raw_Pages: 48 Cleared_Total: 13
# PDF: 194532.pdf Raw_Pages: 113 Cleared_Total: 68
# PDF: 194533.pdf Raw_Pages: 67 Cleared_Total: 35
# PDF: 194534.pdf Raw_Pages: 63 Cleared_Total: 27
# PDF: 194535.pdf Raw_Pages: 90 Cleared_Total: 47
# PDF: 194536.pdf Raw_Pages: 62 Cleared_Total: 33
# PDF: 194537.pdf Raw_Pages: 45 Cleared_Total: 15
# PDF: 194540.pdf Raw_Pages: 58 Cleared_Total: 35
# PDF: 194541.pdf Raw_Pages: 52 Cleared_Total: 26
# PDF: 194542.pdf Raw_Pages: 62 Cleared_Total: 31
# PDF: 194543.pdf Raw_Pages: 74 Cleared_Total: 42
# PDF: 194545.pdf Raw_Pages: 42 Cleared_Total: 16
# PDF: 194549.pdf Raw_Pages: 66 Cleared_Total: 22
# PDF: 194551.pdf Raw_Pages: 118 Cleared_Total: 84
# PDF: 194561.pdf Raw_Pages: 90 Cleared_Total: 63
# PDF: 194563.pdf Raw_Pages: 40 Cleared_Total: 14
# PDF: 194564.pdf Raw_Pages: 57 Cleared_Total: 13
# PDF: 194565.pdf Raw_Pages: 61 Cleared_Total: 28
# PDF: 194566.pdf Raw_Pages: 72 Cleared_Total: 32
# PDF: 194567.pdf Raw_Pages: 63 Cleared_Total: 25
# PDF: 194572.pdf Raw_Pages: 70 Cleared_Total: 32
# PDF: 194573.pdf Raw_Pages: 87 Cleared_Total: 64
# Bozuk pdf: 194574.pdf
# PDF: 194574.pdf Raw_Pages: 35 Cleared_Total: 6
# PDF: 194575.pdf Raw_Pages: 61 Cleared_Total: 30
# PDF: 194576.pdf Raw_Pages: 49 Cleared_Total: 23
# PDF: 194577.pdf Raw_Pages: 68 Cleared_Total: 40
# PDF: 194578.pdf Raw_Pages: 61 Cleared_Total: 22
# PDF: 194579.pdf Raw_Pages: 67 Cleared_Total: 14
# Bozuk pdf: 194580.pdf
# PDF: 194580.pdf Raw_Pages: 69 Cleared_Total: 0
# PDF: 194581.pdf Raw_Pages: 96 Cleared_Total: 61
# PDF: 194582.pdf Raw_Pages: 71 Cleared_Total: 38
# PDF: 194584.pdf Raw_Pages: 49 Cleared_Total: 20
# PDF: 194585.pdf Raw_Pages: 42 Cleared_Total: 14
# PDF: 194586.pdf Raw_Pages: 75 Cleared_Total: 45
# PDF: 194587.pdf Raw_Pages: 61 Cleared_Total: 28
# PDF: 194588.pdf Raw_Pages: 58 Cleared_Total: 27
# PDF: 194589.pdf Raw_Pages: 83 Cleared_Total: 57
# PDF: 194590.pdf Raw_Pages: 89 Cleared_Total: 55
# PDF: 194596.pdf Raw_Pages: 127 Cleared_Total: 88
# PDF: 194597.pdf Raw_Pages: 50 Cleared_Total: 28
# PDF: 194598.pdf Raw_Pages: 106 Cleared_Total: 63
# PDF: 194600.pdf Raw_Pages: 97 Cleared_Total: 62
# PDF: 194601.pdf Raw_Pages: 63 Cleared_Total: 23
# PDF: 194602.pdf Raw_Pages: 101 Cleared_Total: 67
# PDF: 194603.pdf Raw_Pages: 66 Cleared_Total: 15
# PDF: 194604.pdf Raw_Pages: 58 Cleared_Total: 34
# PDF: 194605.pdf Raw_Pages: 86 Cleared_Total: 51
# PDF: 194606.pdf Raw_Pages: 63 Cleared_Total: 22
# PDF: 194607.pdf Raw_Pages: 64 Cleared_Total: 31
# PDF: 194608.pdf Raw_Pages: 84 Cleared_Total: 53
# PDF: 194614.pdf Raw_Pages: 107 Cleared_Total: 82
# PDF: 194615.pdf Raw_Pages: 60 Cleared_Total: 29
# PDF: 194616.pdf Raw_Pages: 178 Cleared_Total: 120
# PDF: 194617.pdf Raw_Pages: 48 Cleared_Total: 23
# PDF: 194618.pdf Raw_Pages: 78 Cleared_Total: 47
# PDF: 194620.pdf Raw_Pages: 73 Cleared_Total: 34
# PDF: 194621.pdf Raw_Pages: 83 Cleared_Total: 53
# PDF: 194623.pdf Raw_Pages: 39 Cleared_Total: 11
# PDF: 194624.pdf Raw_Pages: 87 Cleared_Total: 54
# PDF: 194625.pdf Raw_Pages: 63 Cleared_Total: 32
# PDF: 194626.pdf Raw_Pages: 63 Cleared_Total: 35
# PDF: 194628.pdf Raw_Pages: 91 Cleared_Total: 64
# PDF: 194629.pdf Raw_Pages: 65 Cleared_Total: 30
# PDF: 194630.pdf Raw_Pages: 99 Cleared_Total: 58
# PDF: 194632.pdf Raw_Pages: 72 Cleared_Total: 42
# PDF: 194633.pdf Raw_Pages: 67 Cleared_Total: 31
# PDF: 194634.pdf Raw_Pages: 55 Cleared_Total: 23
# PDF: 194635.pdf Raw_Pages: 219 Cleared_Total: 175
# PDF: 194636.pdf Raw_Pages: 61 Cleared_Total: 18
# PDF: 194638.pdf Raw_Pages: 150 Cleared_Total: 111
# PDF: 194641.pdf Raw_Pages: 275 Cleared_Total: 225
# PDF: 194645.pdf Raw_Pages: 98 Cleared_Total: 57
# PDF: 194647.pdf Raw_Pages: 98 Cleared_Total: 58
# PDF: 194648.pdf Raw_Pages: 228 Cleared_Total: 186
# PDF: 194651.pdf Raw_Pages: 82 Cleared_Total: 43
# PDF: 194653.pdf Raw_Pages: 82 Cleared_Total: 50
# PDF: 194654.pdf Raw_Pages: 35 Cleared_Total: 16
# PDF: 194655.pdf Raw_Pages: 71 Cleared_Total: 30
# PDF: 194659.pdf Raw_Pages: 64 Cleared_Total: 30
# PDF: 194660.pdf Raw_Pages: 68 Cleared_Total: 39
# PDF: 194662.pdf Raw_Pages: 82 Cleared_Total: 40
# PDF: 194687.pdf Raw_Pages: 83 Cleared_Total: 51
# PDF: 194689.pdf Raw_Pages: 101 Cleared_Total: 76
# PDF: 194690.pdf Raw_Pages: 80 Cleared_Total: 43
# PDF: 194691.pdf Raw_Pages: 66 Cleared_Total: 21
# PDF: 194692.pdf Raw_Pages: 55 Cleared_Total: 19
# PDF: 194693.pdf Raw_Pages: 69 Cleared_Total: 31
# PDF: 194694.pdf Raw_Pages: 94 Cleared_Total: 64
# PDF: 194695.pdf Raw_Pages: 101 Cleared_Total: 64
# PDF: 194696.pdf Raw_Pages: 98 Cleared_Total: 68
# PDF: 194697.pdf Raw_Pages: 86 Cleared_Total: 54
# Bozuk pdf: 194698.pdf
# PDF: 194698.pdf Raw_Pages: 151 Cleared_Total: 5
# PDF: 194699.pdf Raw_Pages: 59 Cleared_Total: 27
# PDF: 194700.pdf Raw_Pages: 63 Cleared_Total: 21
# PDF: 194701.pdf Raw_Pages: 88 Cleared_Total: 46
# PDF: 194702.pdf Raw_Pages: 82 Cleared_Total: 43
# PDF: 194703.pdf Raw_Pages: 57 Cleared_Total: 14
# PDF: 194704.pdf Raw_Pages: 94 Cleared_Total: 61
# PDF: 194705.pdf Raw_Pages: 96 Cleared_Total: 57
# PDF: 194707.pdf Raw_Pages: 43 Cleared_Total: 8
# PDF: 194708.pdf Raw_Pages: 96 Cleared_Total: 54
# PDF: 194709.pdf Raw_Pages: 66 Cleared_Total: 33
# PDF: 194711.pdf Raw_Pages: 87 Cleared_Total: 40
# PDF: 194713.pdf Raw_Pages: 56 Cleared_Total: 22
# PDF: 194717.pdf Raw_Pages: 75 Cleared_Total: 37
# PDF: 194718.pdf Raw_Pages: 98 Cleared_Total: 53
# PDF: 194719.pdf Raw_Pages: 62 Cleared_Total: 19
# PDF: 194720.pdf Raw_Pages: 80 Cleared_Total: 46
# PDF: 194721.pdf Raw_Pages: 45 Cleared_Total: 21
# PDF: 194722.pdf Raw_Pages: 72 Cleared_Total: 35
# PDF: 194723.pdf Raw_Pages: 68 Cleared_Total: 36
# PDF: 194724.pdf Raw_Pages: 105 Cleared_Total: 71
# PDF: 194725.pdf Raw_Pages: 72 Cleared_Total: 39
# Bozuk pdf: 194726.pdf
# PDF: 194726.pdf Raw_Pages: 70 Cleared_Total: 0
# Bozuk pdf: 194727.pdf
# PDF: 194727.pdf Raw_Pages: 60 Cleared_Total: 0
# PDF: 194728.pdf Raw_Pages: 48 Cleared_Total: 19
# PDF: 194729.pdf Raw_Pages: 114 Cleared_Total: 81
# PDF: 194730.pdf Raw_Pages: 63 Cleared_Total: 27
# PDF: 194731.pdf Raw_Pages: 260 Cleared_Total: 163
# PDF: 194743.pdf Raw_Pages: 53 Cleared_Total: 20
# PDF: 194744.pdf Raw_Pages: 76 Cleared_Total: 46
# PDF: 194750.pdf Raw_Pages: 100 Cleared_Total: 65
# PDF: 194752.pdf Raw_Pages: 114 Cleared_Total: 72
# PDF: 194753.pdf Raw_Pages: 85 Cleared_Total: 36
# PDF: 194754.pdf Raw_Pages: 73 Cleared_Total: 26
# PDF: 194770.pdf Raw_Pages: 75 Cleared_Total: 41
# PDF: 194791.pdf Raw_Pages: 75 Cleared_Total: 43
# PDF: 194793.pdf Raw_Pages: 73 Cleared_Total: 40
# PDF: 194794.pdf Raw_Pages: 68 Cleared_Total: 36
# PDF: 194795.pdf Raw_Pages: 76 Cleared_Total: 38
# PDF: 194796.pdf Raw_Pages: 102 Cleared_Total: 56
# PDF: 194797.pdf Raw_Pages: 133 Cleared_Total: 87
# PDF: 194798.pdf Raw_Pages: 49 Cleared_Total: 11
# PDF: 194799.pdf Raw_Pages: 102 Cleared_Total: 68
# PDF: 194800.pdf Raw_Pages: 82 Cleared_Total: 41
# PDF: 194801.pdf Raw_Pages: 62 Cleared_Total: 33
# PDF: 194802.pdf Raw_Pages: 73 Cleared_Total: 40
# PDF: 194803.pdf Raw_Pages: 46 Cleared_Total: 19
# PDF: 194819.pdf Raw_Pages: 47 Cleared_Total: 10
# PDF: 194820.pdf Raw_Pages: 30 Cleared_Total: 10
# PDF: 194821.pdf Raw_Pages: 76 Cleared_Total: 28
# PDF: 194822.pdf Raw_Pages: 54 Cleared_Total: 13
# PDF: 194839.pdf Raw_Pages: 95 Cleared_Total: 65
# PDF: 194840.pdf Raw_Pages: 76 Cleared_Total: 48
# PDF: 194842.pdf Raw_Pages: 92 Cleared_Total: 64
# PDF: 194844.pdf Raw_Pages: 84 Cleared_Total: 59
# PDF: 194846.pdf Raw_Pages: 98 Cleared_Total: 59
# PDF: 194847.pdf Raw_Pages: 99 Cleared_Total: 65
# PDF: 194864.pdf Raw_Pages: 94 Cleared_Total: 51
# PDF: 194865.pdf Raw_Pages: 94 Cleared_Total: 62
# PDF: 194866.pdf Raw_Pages: 130 Cleared_Total: 85
# PDF: 194867.pdf Raw_Pages: 110 Cleared_Total: 79
# PDF: 194868.pdf Raw_Pages: 146 Cleared_Total: 117
# PDF: 194869.pdf Raw_Pages: 87 Cleared_Total: 46
# PDF: 194870.pdf Raw_Pages: 68 Cleared_Total: 34
# PDF: 194871.pdf Raw_Pages: 119 Cleared_Total: 73
# PDF: 194873.pdf Raw_Pages: 174 Cleared_Total: 138
# Bozuk pdf: 194874.pdf
# PDF: 194874.pdf Raw_Pages: 61 Cleared_Total: 0
# PDF: 194876.pdf Raw_Pages: 81 Cleared_Total: 49
# PDF: 194877.pdf Raw_Pages: 68 Cleared_Total: 32
# PDF: 194878.pdf Raw_Pages: 73 Cleared_Total: 33
# PDF: 194879.pdf Raw_Pages: 71 Cleared_Total: 28
# PDF: 194881.pdf Raw_Pages: 130 Cleared_Total: 86
# PDF: 194882.pdf Raw_Pages: 89 Cleared_Total: 57
# PDF: 194883.pdf Raw_Pages: 60 Cleared_Total: 27
# PDF: 194884.pdf Raw_Pages: 75 Cleared_Total: 40
# PDF: 194886.pdf Raw_Pages: 82 Cleared_Total: 53
# PDF: 194887.pdf Raw_Pages: 66 Cleared_Total: 28
# PDF: 194889.pdf Raw_Pages: 61 Cleared_Total: 36
# PDF: 194890.pdf Raw_Pages: 74 Cleared_Total: 36
# PDF: 194891.pdf Raw_Pages: 62 Cleared_Total: 32
# PDF: 194892.pdf Raw_Pages: 89 Cleared_Total: 61
# PDF: 194893.pdf Raw_Pages: 62 Cleared_Total: 34
# PDF: 194894.pdf Raw_Pages: 51 Cleared_Total: 20
# PDF: 194895.pdf Raw_Pages: 101 Cleared_Total: 73
# PDF: 194896.pdf Raw_Pages: 93 Cleared_Total: 52
# PDF: 194897.pdf Raw_Pages: 80 Cleared_Total: 40
# PDF: 194898.pdf Raw_Pages: 57 Cleared_Total: 33
# PDF: 194899.pdf Raw_Pages: 108 Cleared_Total: 75
# PDF: 194900.pdf Raw_Pages: 59 Cleared_Total: 31
# PDF: 194901.pdf Raw_Pages: 63 Cleared_Total: 44
# PDF: 194902.pdf Raw_Pages: 68 Cleared_Total: 44
# PDF: 194903.pdf Raw_Pages: 80 Cleared_Total: 49
# Bozuk pdf: 194905.pdf
# PDF: 194905.pdf Raw_Pages: 74 Cleared_Total: 0
# Bozuk pdf: 194906.pdf
# PDF: 194906.pdf Raw_Pages: 77 Cleared_Total: 0
# PDF: 194907.pdf Raw_Pages: 73 Cleared_Total: 36
# PDF: 194908.pdf Raw_Pages: 72 Cleared_Total: 52
# PDF: 194909.pdf Raw_Pages: 44 Cleared_Total: 26
# PDF: 194910.pdf Raw_Pages: 42 Cleared_Total: 19
# PDF: 194911.pdf Raw_Pages: 83 Cleared_Total: 57
# PDF: 194912.pdf Raw_Pages: 60 Cleared_Total: 27
# PDF: 194913.pdf Raw_Pages: 111 Cleared_Total: 67
# PDF: 194915.pdf Raw_Pages: 80 Cleared_Total: 54
# PDF: 194916.pdf Raw_Pages: 59 Cleared_Total: 19
# PDF: 194917.pdf Raw_Pages: 100 Cleared_Total: 65
# PDF: 194920.pdf Raw_Pages: 70 Cleared_Total: 41
# PDF: 194921.pdf Raw_Pages: 81 Cleared_Total: 44
# PDF: 194922.pdf Raw_Pages: 74 Cleared_Total: 38
# PDF: 194923.pdf Raw_Pages: 160 Cleared_Total: 140
# PDF: 194924.pdf Raw_Pages: 65 Cleared_Total: 39
# PDF: 194925.pdf Raw_Pages: 81 Cleared_Total: 58
# PDF: 194926.pdf Raw_Pages: 39 Cleared_Total: 9
# PDF: 194927.pdf Raw_Pages: 91 Cleared_Total: 55
# PDF: 194928.pdf Raw_Pages: 57 Cleared_Total: 17
# PDF: 194929.pdf Raw_Pages: 86 Cleared_Total: 53
# PDF: 194930.pdf Raw_Pages: 58 Cleared_Total: 27
# PDF: 194931.pdf Raw_Pages: 58 Cleared_Total: 27
# PDF: 194933.pdf Raw_Pages: 61 Cleared_Total: 24
# PDF: 194934.pdf Raw_Pages: 73 Cleared_Total: 34
# PDF: 194936.pdf Raw_Pages: 102 Cleared_Total: 59
# PDF: 194939.pdf Raw_Pages: 70 Cleared_Total: 32
# PDF: 194940.pdf Raw_Pages: 38 Cleared_Total: 13
# PDF: 194941.pdf Raw_Pages: 82 Cleared_Total: 49
# PDF: 194942.pdf Raw_Pages: 134 Cleared_Total: 94
# PDF: 194943.pdf Raw_Pages: 76 Cleared_Total: 36
# Bozuk pdf: 194944.pdf
# PDF: 194944.pdf Raw_Pages: 66 Cleared_Total: 0
# PDF: 194945.pdf Raw_Pages: 51 Cleared_Total: 23
# Bozuk pdf: 194946.pdf
# PDF: 194946.pdf Raw_Pages: 62 Cleared_Total: 0
# PDF: 194947.pdf Raw_Pages: 133 Cleared_Total: 103
# PDF: 194948.pdf Raw_Pages: 69 Cleared_Total: 29
# PDF: 194949.pdf Raw_Pages: 122 Cleared_Total: 68
# PDF: 194950.pdf Raw_Pages: 114 Cleared_Total: 79
# PDF: 194953.pdf Raw_Pages: 97 Cleared_Total: 67
# PDF: 194954.pdf Raw_Pages: 161 Cleared_Total: 114
# Bozuk pdf: 194956.pdf
# PDF: 194956.pdf Raw_Pages: 171 Cleared_Total: 0
# PDF: 194958.pdf Raw_Pages: 67 Cleared_Total: 22
# PDF: 194964.pdf Raw_Pages: 116 Cleared_Total: 82
# PDF: 194965.pdf Raw_Pages: 121 Cleared_Total: 86
# PDF: 194966.pdf Raw_Pages: 142 Cleared_Total: 89
# PDF: 194967.pdf Raw_Pages: 122 Cleared_Total: 82
# PDF: 194968.pdf Raw_Pages: 120 Cleared_Total: 89
# PDF: 194969.pdf Raw_Pages: 115 Cleared_Total: 75
# PDF: 194970.pdf Raw_Pages: 56 Cleared_Total: 20
# PDF: 194971.pdf Raw_Pages: 127 Cleared_Total: 89
# PDF: 194972.pdf Raw_Pages: 77 Cleared_Total: 33
# PDF: 194973.pdf Raw_Pages: 174 Cleared_Total: 125
# Bozuk pdf: 194974.pdf
# PDF: 194974.pdf Raw_Pages: 131 Cleared_Total: 0
# PDF: 194976.pdf Raw_Pages: 122 Cleared_Total: 77
# PDF: 194978.pdf Raw_Pages: 77 Cleared_Total: 39
# PDF: 194979.pdf Raw_Pages: 55 Cleared_Total: 18
# PDF: 194980.pdf Raw_Pages: 235 Cleared_Total: 188
# PDF: 194981.pdf Raw_Pages: 57 Cleared_Total: 26
# PDF: 194982.pdf Raw_Pages: 123 Cleared_Total: 80
# PDF: 194984.pdf Raw_Pages: 76 Cleared_Total: 43
# PDF: 194985.pdf Raw_Pages: 83 Cleared_Total: 45
# PDF: 194986.pdf Raw_Pages: 147 Cleared_Total: 118
# PDF: 194987.pdf Raw_Pages: 179 Cleared_Total: 135
# Bozuk pdf: 194988.pdf
# PDF: 194988.pdf Raw_Pages: 168 Cleared_Total: 0
# PDF: 194989.pdf Raw_Pages: 121 Cleared_Total: 64
# PDF: 194991.pdf Raw_Pages: 76 Cleared_Total: 28
# PDF: 194993.pdf Raw_Pages: 75 Cleared_Total: 31
# PDF: 194994.pdf Raw_Pages: 250 Cleared_Total: 204
# PDF: 194996.pdf Raw_Pages: 100 Cleared_Total: 72
# PDF: 194997.pdf Raw_Pages: 180 Cleared_Total: 122
# PDF: 194998.pdf Raw_Pages: 127 Cleared_Total: 92
# PDF: 194999.pdf Raw_Pages: 59 Cleared_Total: 17
# PDF: 195000.pdf Raw_Pages: 98 Cleared_Total: 51
# PDF: 195001.pdf Raw_Pages: 99 Cleared_Total: 46
# PDF: 195004.pdf Raw_Pages: 89 Cleared_Total: 48
# PDF: 195005.pdf Raw_Pages: 110 Cleared_Total: 70
# PDF: 195006.pdf Raw_Pages: 81 Cleared_Total: 41
# PDF: 195007.pdf Raw_Pages: 79 Cleared_Total: 37
# PDF: 195008.pdf Raw_Pages: 111 Cleared_Total: 73
# Bozuk pdf: 195009.pdf
# PDF: 195009.pdf Raw_Pages: 157 Cleared_Total: 0
# PDF: 195010.pdf Raw_Pages: 82 Cleared_Total: 40
# PDF: 195012.pdf Raw_Pages: 138 Cleared_Total: 108
# PDF: 195013.pdf Raw_Pages: 111 Cleared_Total: 71
# PDF: 195014.pdf Raw_Pages: 133 Cleared_Total: 88
# PDF: 195015.pdf Raw_Pages: 118 Cleared_Total: 81
# PDF: 195016.pdf Raw_Pages: 48 Cleared_Total: 11
# PDF: 195018.pdf Raw_Pages: 65 Cleared_Total: 24
# PDF: 195020.pdf Raw_Pages: 64 Cleared_Total: 33
# PDF: 195023.pdf Raw_Pages: 79 Cleared_Total: 43
# PDF: 195024.pdf Raw_Pages: 49 Cleared_Total: 22
# PDF: 195025.pdf Raw_Pages: 97 Cleared_Total: 72
# PDF: 195026.pdf Raw_Pages: 52 Cleared_Total: 11
# PDF: 195027.pdf Raw_Pages: 61 Cleared_Total: 29
# PDF: 195029.pdf Raw_Pages: 78 Cleared_Total: 37
# PDF: 195030.pdf Raw_Pages: 61 Cleared_Total: 24
# PDF: 195032.pdf Raw_Pages: 72 Cleared_Total: 35
# PDF: 195033.pdf Raw_Pages: 71 Cleared_Total: 34
# PDF: 195035.pdf Raw_Pages: 74 Cleared_Total: 43
# PDF: 195036.pdf Raw_Pages: 55 Cleared_Total: 18
# PDF: 195037.pdf Raw_Pages: 86 Cleared_Total: 40
# PDF: 195038.pdf Raw_Pages: 103 Cleared_Total: 63
# PDF: 195039.pdf Raw_Pages: 86 Cleared_Total: 53
# PDF: 195040.pdf Raw_Pages: 92 Cleared_Total: 65
# PDF: 195041.pdf Raw_Pages: 173 Cleared_Total: 132
# PDF: 195042.pdf Raw_Pages: 89 Cleared_Total: 56
# PDF: 195043.pdf Raw_Pages: 109 Cleared_Total: 77
# PDF: 195044.pdf Raw_Pages: 116 Cleared_Total: 74
# PDF: 195045.pdf Raw_Pages: 131 Cleared_Total: 87
# PDF: 195046.pdf Raw_Pages: 84 Cleared_Total: 43
# PDF: 195048.pdf Raw_Pages: 59 Cleared_Total: 27
# PDF: 195049.pdf Raw_Pages: 86 Cleared_Total: 50
# PDF: 195050.pdf Raw_Pages: 65 Cleared_Total: 27
# PDF: 195052.pdf Raw_Pages: 105 Cleared_Total: 66
# PDF: 195053.pdf Raw_Pages: 100 Cleared_Total: 72
# PDF: 195054.pdf Raw_Pages: 75 Cleared_Total: 34
# PDF: 195055.pdf Raw_Pages: 82 Cleared_Total: 52
# PDF: 195056.pdf Raw_Pages: 93 Cleared_Total: 67
# PDF: 195057.pdf Raw_Pages: 81 Cleared_Total: 47
# PDF: 195058.pdf Raw_Pages: 70 Cleared_Total: 28
# PDF: 195059.pdf Raw_Pages: 50 Cleared_Total: 12
# PDF: 195060.pdf Raw_Pages: 41 Cleared_Total: 11
# PDF: 195061.pdf Raw_Pages: 144 Cleared_Total: 119
# PDF: 195062.pdf Raw_Pages: 62 Cleared_Total: 26
# PDF: 195063.pdf Raw_Pages: 72 Cleared_Total: 35
# PDF: 195064.pdf Raw_Pages: 82 Cleared_Total: 52
# PDF: 195065.pdf Raw_Pages: 64 Cleared_Total: 31
# PDF: 195066.pdf Raw_Pages: 41 Cleared_Total: 13
# PDF: 195067.pdf Raw_Pages: 58 Cleared_Total: 23
# PDF: 195068.pdf Raw_Pages: 58 Cleared_Total: 17
# PDF: 195069.pdf Raw_Pages: 52 Cleared_Total: 17
# PDF: 195070.pdf Raw_Pages: 69 Cleared_Total: 29
# PDF: 195071.pdf Raw_Pages: 110 Cleared_Total: 67
# PDF: 195072.pdf Raw_Pages: 173 Cleared_Total: 131
# PDF: 195073.pdf Raw_Pages: 122 Cleared_Total: 75
# PDF: 195074.pdf Raw_Pages: 81 Cleared_Total: 49
# PDF: 195075.pdf Raw_Pages: 80 Cleared_Total: 37
# PDF: 195076.pdf Raw_Pages: 103 Cleared_Total: 75
# PDF: 195077.pdf Raw_Pages: 162 Cleared_Total: 107
# PDF: 195078.pdf Raw_Pages: 130 Cleared_Total: 67
# PDF: 195079.pdf Raw_Pages: 107 Cleared_Total: 83
# Bozuk pdf: 195081.pdf
# PDF: 195081.pdf Raw_Pages: 57 Cleared_Total: 0
# PDF: 195082.pdf Raw_Pages: 59 Cleared_Total: 28
# PDF: 195083.pdf Raw_Pages: 78 Cleared_Total: 48
# PDF: 195084.pdf Raw_Pages: 58 Cleared_Total: 27
# PDF: 195085.pdf Raw_Pages: 48 Cleared_Total: 23
# PDF: 195087.pdf Raw_Pages: 54 Cleared_Total: 22
# PDF: 195088.pdf Raw_Pages: 49 Cleared_Total: 31
# PDF: 195089.pdf Raw_Pages: 47 Cleared_Total: 23
# PDF: 195090.pdf Raw_Pages: 72 Cleared_Total: 33
# PDF: 195092.pdf Raw_Pages: 61 Cleared_Total: 22
