# %%
from io import StringIO

import os
import re
import PyPDF2
from pdfminer.high_level import extract_pages, extract_text
from pdfminer.layout import LTTextContainer, LTChar, LTRect, LTFigure, LAParams
from ftlangdetect import detect

# %%
def collect_clear_text(text_list):
    text_list = [re.sub(r'\s+', ' ', text_.strip()).strip() for text_ in text_list]
    text = ' '.join(text_list)
    return text.strip()

def contents_references_rmv(text_per_page: dict,pages = 30, char_num = 600, years_num = 10):
    
    def less_char_drop(text,char_num):
        if len(text) < char_num: return True
    def dot_drop(text):
        if (len(text) > char_num) and ((text.count(".") > 40) or (text.count("…")> 10) or (text.count("_")> 10) or (text.count("-")>10)) : return True
    def referencesYear_drop(text):
        year_list = list(range(1900,2025))
        year_count = 0
        for year in year_list:
            if str(year) in text:
                year_count += 1
        if year_count > years_num: return True
    total_pages = len(text_per_page)
    obs_numbers = list(range(0,pages)) + list(range(total_pages-pages,total_pages))
    for page_num in obs_numbers:
        page_word = f'Page_{page_num}'
        if page_num < pages:
            try:
                if (less_char_drop(text_per_page[page_word],char_num)) or (dot_drop(text_per_page[page_word]))  : del text_per_page[page_word]   
            except KeyError:
                continue
        else:
            if (less_char_drop(text_per_page[page_word],char_num)) or (referencesYear_drop(text_per_page[page_word]))  : del text_per_page[page_word]
    return text_per_page

def remove_eng(text_per_page: dict):
    dict_keys = list(text_per_page.keys())
    for keys in dict_keys: 
        text = text_per_page[keys]
        lang = detect(text)
        #print(keys, lang)
        if (lang["lang"] == 'tr') and (lang["score"] < 0.75):
            del text_per_page[keys]
        elif lang["lang"] != "tr":
            del text_per_page[keys]
    return text_per_page

def remove_pageNum(text: str):
    text = text.strip(" ")
    text_list = text.split(" ")
    if text_list[0].strip().isnumeric():
        text_list.remove(text_list[0])
    if text_list[-1].strip().isnumeric():
        text_list.remove(text_list[-1])

    return " ".join(text_list).strip()

# %%
pdf_listDir = os.listdir("kütüphane_pdf") 
for pdf in pdf_listDir:
    text_per_page = {}
    pdf_path = f'kütüphane_pdf/{pdf}'
    for pagenum, page in enumerate(extract_pages(pdf_path, laparams = LAParams(line_margin = 2))):
        page_text = []
        page_elements = [(element.y1, element) for element in page._objs]
        page_elements.sort(key=lambda a: a[0], reverse=True)
        for i, component in enumerate(page_elements):
            element = component[1]
            if isinstance(element, LTTextContainer):
                line_text = element.get_text()
                page_text.append(line_text)
        dctkey = 'Page_'+str(pagenum)
        text_per_page[dctkey]= collect_clear_text(page_text)
    rawTotal = len(text_per_page)
    text_per_page = contents_references_rmv(text_per_page=text_per_page)
    text_per_page = remove_eng(text_per_page=text_per_page)

    clearedTotal = len(text_per_page)
    if clearedTotal < 2:
        print("Bozuk pdf:", pdf)
    print("PDF:", pdf, "Raw_Pages:", rawTotal, "Cleared_Total:", clearedTotal)
    with open(f"txt_folder/{pdf[:-4]}.txt" , 'w+', encoding="utf-8") as txt:
        for text in text_per_page.values():
            txt.write(remove_pageNum(text))
            txt.write('\n')
    os.rename( f"kütüphane_pdf/{pdf}", f"kütüp_pdfFin/finished_{pdf}")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# PDF: 1136-420.pdf Raw_Pages: 269 Cleared_Total: 258
# PDF: 30ogk-acis.pdf Raw_Pages: 15 Cleared_Total: 9
# PDF: 434-av.pdf Raw_Pages: 112 Cleared_Total: 77
# PDF: 435-m.pdf Raw_Pages: 356 Cleared_Total: 243
# PDF: 436-d.pdf Raw_Pages: 160 Cleared_Total: 130
# PDF: 437-a.pdf Raw_Pages: 336 Cleared_Total: 272
# PDF: 444-tubakkom.pdf Raw_Pages: 473 Cleared_Total: 383
# PDF: 445-has.pdf Raw_Pages: 89 Cleared_Total: 62
# PDF: 447-hsss.pdf Raw_Pages: 185 Cleared_Total: 141
# PDF: 448-tbk.pdf Raw_Pages: 325 Cleared_Total: 287
# PDF: 449-ihp.pdf Raw_Pages: 580 Cleared_Total: 529
# PDF: 450.pdf Raw_Pages: 112 Cleared_Total: 92
# PDF: 452.pdf Raw_Pages: 488 Cleared_Total: 428
# PDF: 456.pdf Raw_Pages: 176 Cleared_Total: 150
# PDF: 463.pdf Raw_Pages: 144 Cleared_Total: 114
# PDF: 467.pdf Raw_Pages: 48 Cleared_Total: 32
# PDF: 468.pdf Raw_Pages: 416 Cleared_Total: 378
# PDF: 469.pdf Raw_Pages: 32 Cleared_Total: 13
# PDF: 470.pdf Raw_Pages: 112 Cleared_Total: 91
# PDF: 475.pdf Raw_Pages: 144 Cleared_Total: 109
# PDF: 476.pdf Raw_Pages: 53 Cleared_Total: 42
# PDF: 477.pdf Raw_Pages: 228 Cleared_Total: 187
# PDF: abhukukuveekonomi.pdf Raw_Pages: 133 Cleared_Total: 108
# PDF: ab_hukuku.pdf Raw_Pages: 108 Cleared_Total: 78
# PDF: ab_hukuku_av_kurumlari.pdf Raw_Pages: 391 Cleared_Total: 360
# PDF: ah-ufy-2011.pdf Raw_Pages: 57 Cleared_Total: 3
# PDF: aihm_cezayargilamasi.pdf Raw_Pages: 308 Cleared_Total: 264
# PDF: aihs-294.pdf Raw_Pages: 371 Cleared_Total: 343
# PDF: aky-1973-310.pdf Raw_Pages: 37 Cleared_Total: 29
# PDF: ambb-2011-382.pdf Raw_Pages: 157 Cleared_Total: 133
# PDF: ao-2007-354.pdf Raw_Pages: 437 Cleared_Total: 410
# PDF: avk-2008-276.pdf Raw_Pages: 159 Cleared_Total: 152
# PDF: avkanunu.pdf Raw_Pages: 488 Cleared_Total: 421
# PDF: ayad-2010-383.pdf Raw_Pages: 357 Cleared_Total: 328
# PDF: bek-2007-315.pdf Raw_Pages: 25 Cleared_Total: 19
# PDF: bilimsel-acidan-marmara (1).pdf Raw_Pages: 297 Cleared_Total: 189
# PDF: bilimsel-acidan-marmara.pdf Raw_Pages: 297 Cleared_Total: 189
# PDF: cevre-sorunlari.pdf Raw_Pages: 170 Cleared_Total: 154
# PDF: cmk-2007-316.pdf Raw_Pages: 85 Cleared_Total: 63
# PDF: cmk-419.pdf Raw_Pages: 148 Cleared_Total: 124
# PDF: cocukiadesi.pdf Raw_Pages: 131 Cleared_Total: 112
# PDF: cogulcu-demokrasi.pdf Raw_Pages: 352 Cleared_Total: 318
# PDF: d142-10.pdf Raw_Pages: 23 Cleared_Total: 7
# PDF: d143-11.pdf Raw_Pages: 20 Cleared_Total: 9
# PDF: forum2.pdf Raw_Pages: 111 Cleared_Total: 97
# PDF: forum3.pdf Raw_Pages: 117 Cleared_Total: 107
# PDF: forum4.pdf Raw_Pages: 132 Cleared_Total: 121
# PDF: forum5.pdf Raw_Pages: 90 Cleared_Total: 77
# PDF: forum6.pdf Raw_Pages: 77 Cleared_Total: 63
# PDF: forum7.pdf Raw_Pages: 260 Cleared_Total: 201
# PDF: hktdtd-422.pdf Raw_Pages: 169 Cleared_Total: 146
# PDF: hmkanunu.pdf Raw_Pages: 295 Cleared_Total: 244
# PDF: hsss-421.pdf Raw_Pages: 169 Cleared_Total: 126
# PDF: iletisim-ozgurlugune-mudahale.pdf Raw_Pages: 106 Cleared_Total: 76
# PDF: infaz_hukuku.pdf Raw_Pages: 177 Cleared_Total: 147
# PDF: kthdc-418.pdf Raw_Pages: 84 Cleared_Total: 69
# PDF: lubnan_konferans.pdf Raw_Pages: 242 Cleared_Total: 105
# PDF: medeni-usul-5.pdf Raw_Pages: 272 Cleared_Total: 259
# PDF: medeni-usul-7.pdf Raw_Pages: 324 Cleared_Total: 219
# PDF: medeni-usul-8.pdf Raw_Pages: 536 Cleared_Total: 345
# PDF: medeniusul_toplanti_2.pdf Raw_Pages: 521 Cleared_Total: 483
# PDF: Medeni_Usul_6.pdf Raw_Pages: 302 Cleared_Total: 283
# PDF: meslege-yeni-baslayan-avukat-forum1.pdf Raw_Pages: 156 Cleared_Total: 141
# PDF: miep-sr.pdf Raw_Pages: 256 Cleared_Total: 60
# PDF: mu-2005-327.pdf Raw_Pages: 347 Cleared_Total: 322
# PDF: oo-08-09.pdf Raw_Pages: 65 Cleared_Total: 60
# PDF: oo-2005-336.pdf Raw_Pages: 31 Cleared_Total: 23
# PDF: oo-2006-335.pdf Raw_Pages: 44 Cleared_Total: 38
# PDF: oo-2007-345.pdf Raw_Pages: 49 Cleared_Total: 45
# PDF: oo-2008-346.pdf Raw_Pages: 33 Cleared_Total: 31
# PDF: oo-yy-02-09.pdf Raw_Pages: 180 Cleared_Total: 157
# PDF: oym-2010-387.pdf Raw_Pages: 109 Cleared_Total: 76
# PDF: ozel-yasamin-gizliligi.pdf Raw_Pages: 123 Cleared_Total: 97
# PDF: savcilik.pdf Raw_Pages: 349 Cleared_Total: 336
# PDF: shd-2011-385.pdf Raw_Pages: 161 Cleared_Total: 136
# PDF: sorularla-aihm.pdf Raw_Pages: 742 Cleared_Total: 710
# PDF: sorularla-bireysel-is-hukuku-cilt1.pdf Raw_Pages: 627 Cleared_Total: 579
# PDF: sorularla-medeni-usul-hukuku.pdf Raw_Pages: 222 Cleared_Total: 198
# PDF: sorularla-toplu-is-hukuku.pdf Raw_Pages: 480 Cleared_Total: 439
# PDF: sorularla_cmk.pdf Raw_Pages: 668 Cleared_Total: 608
# PDF: sorularla_kadina_yonelik.pdf Raw_Pages: 276 Cleared_Total: 246
# PDF: ss-2007.pdf Raw_Pages: 47 Cleared_Total: 27
# PDF: tbb-b-yy-acis.pdf Raw_Pages: 340 Cleared_Total: 287
# PDF: tbkanunu.pdf Raw_Pages: 376 Cleared_Total: 308
# PDF: tbkt-2008-262.pdf Raw_Pages: 111 Cleared_Total: 105
# PDF: tck-kb.pdf Raw_Pages: 645 Cleared_Total: 517
# PDF: tck301.pdf Raw_Pages: 92 Cleared_Total: 73
# PDF: tubakkom.pdf Raw_Pages: 324 Cleared_Total: 267
# PDF: tubakkom7.pdf Raw_Pages: 306 Cleared_Total: 261
# PDF: tuketicinin-korunmasi-hakkinda-kanun.pdf Raw_Pages: 521 Cleared_Total: 492
# PDF: turk-ceza-kanunu-kabahatlar-kanunu.pdf Raw_Pages: 486 Cleared_Total: 347
# PDF: turk-ticaret-kanunu-tasarisi.pdf Raw_Pages: 357 Cleared_Total: 330
# PDF: turkiyede-hukuk-egitimi.pdf Raw_Pages: 231 Cleared_Total: 185
# PDF: Turk_Ticaret_Kanunu.pdf Raw_Pages: 1112 Cleared_Total: 1039
# PDF: uluslararasi_uyusmazlik_semp.pdf Raw_Pages: 198 Cleared_Total: 165
# PDF: vac-yy-11-12.pdf Raw_Pages: 38 Cleared_Total: 20
# PDF: yargi-reformu.pdf Raw_Pages: 633 Cleared_Total: 596
# PDF: Özdemir Özok.pdf Raw_Pages: 54 Cleared_Total: 43
