# %%
from io import StringIO

import os
import re
import PyPDF2
from pdfminer.high_level import extract_pages, extract_text
from pdfminer.layout import LTTextContainer, LTChar, LTRect, LTFigure, LAParams
from ftlangdetect import detect

# %%
def collect_clear_text(text_list):
    text_list = [re.sub(r'\s+', ' ', text_.strip()).strip() for text_ in text_list]
    text = ' '.join(text_list)
    return text.strip()

def contents_references_rmv(text_per_page: dict,pages = 30, char_num = 600, years_num = 10):
    
    def less_char_drop(text,char_num):
        if len(text) < char_num: return True
    def dot_drop(text):
        if (len(text) > char_num) and ((text.count(".") > 40) or (text.count("…")> 10) or (text.count("_")> 10) or (text.count("-")>10)) : return True
    def referencesYear_drop(text):
        year_list = list(range(1900,2025))
        year_count = 0
        for year in year_list:
            if str(year) in text:
                year_count += 1
        if year_count > years_num: return True
    total_pages = len(text_per_page)
    obs_numbers = list(range(0,pages)) + list(range(total_pages-pages,total_pages))
    for page_num in obs_numbers:
        page_word = f'Page_{page_num}'
        if page_num < pages:
            try:
                if (less_char_drop(text_per_page[page_word],char_num)) or (dot_drop(text_per_page[page_word]))  : del text_per_page[page_word]   
            except KeyError:
                continue
        else:
            if (less_char_drop(text_per_page[page_word],char_num)) or (referencesYear_drop(text_per_page[page_word]))  : del text_per_page[page_word]
    return text_per_page

def remove_eng(text_per_page: dict):
    dict_keys = list(text_per_page.keys())
    for keys in dict_keys: 
        text = text_per_page[keys]
        lang = detect(text)
        #print(keys, lang)
        if (lang["lang"] == 'tr') and (lang["score"] < 0.75):
            del text_per_page[keys]
        elif lang["lang"] != "tr":
            del text_per_page[keys]
    return text_per_page

def remove_pageNum(text: str):
    text = text.strip(" ")
    text_list = text.split(" ")
    if text_list[0].strip().isnumeric():
        text_list.remove(text_list[0])
    if text_list[-1].strip().isnumeric():
        text_list.remove(text_list[-1])

    return " ".join(text_list).strip()

# %%
pdf_listDir = os.listdir("Kararlar Dergisi/PDFs") 
for pdf in pdf_listDir:
    print(pdf)
    text_per_page = {}
    pdf_path = f'Kararlar Dergisi/PDFs/{pdf}'
    for pagenum, page in enumerate(extract_pages(pdf_path, laparams = LAParams(line_margin = 2))):
        page_text = []
        page_elements = [(element.y1, element) for element in page._objs]
        page_elements.sort(key=lambda a: a[0], reverse=True)
        for i, component in enumerate(page_elements):
            element = component[1]
            if isinstance(element, LTTextContainer):
                line_text = element.get_text()
                page_text.append(line_text)
        dctkey = 'Page_'+str(pagenum)
        text_per_page[dctkey]= collect_clear_text(page_text)
    rawTotal = len(text_per_page)
    text_per_page = contents_references_rmv(text_per_page=text_per_page)
    text_per_page = remove_eng(text_per_page=text_per_page)

    clearedTotal = len(text_per_page)
    if clearedTotal < 2:
        print("Bozuk pdf:", pdf)
    print("PDF:", pdf, "Raw_Pages:", rawTotal, "Cleared_Total:", clearedTotal)
    with open(f"Kararlar Dergisi/txt_folder/{pdf[:-4]}.txt" , 'w+', encoding="utf-8") as txt:
        for text in text_per_page.values():
            txt.write(remove_pageNum(text))
            txt.write('\n')
    os.rename( f"Kararlar Dergisi/PDFs/{pdf}", f"Kararlar Dergisi/PDFs_fin/finished_{pdf}")
# Out:
# 01_cilt_kararlar_dergisi_59.pdf
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# PDF: 01_cilt_kararlar_dergisi_59.pdf Raw_Pages: 740 Cleared_Total: 694
# 02_cilt_kararlar_dergisi_58_son_compressed.pdf
# PDF: 02_cilt_kararlar_dergisi_58_son_compressed.pdf Raw_Pages: 992 Cleared_Total: 941
# 02_cilt_kararlar_dergisi_59.pdf
# PDF: 02_cilt_kararlar_dergisi_59.pdf Raw_Pages: 759 Cleared_Total: 709
# 03_cilt_kararlar_dergisi_58_son_compressed.pdf
# PDF: 03_cilt_kararlar_dergisi_58_son_compressed.pdf Raw_Pages: 897 Cleared_Total: 749
# 03_cilt_kararlar_dergisi_59.pdf
# PDF: 03_cilt_kararlar_dergisi_59.pdf Raw_Pages: 775 Cleared_Total: 654
# aymkd36cilt1.pdf
# PDF: aymkd36cilt1.pdf Raw_Pages: 530 Cleared_Total: 505
# aymkd36cilt2.pdf
# PDF: aymkd36cilt2.pdf Raw_Pages: 552 Cleared_Total: 524
# aymkd37cilt1.pdf
# PDF: aymkd37cilt1.pdf Raw_Pages: 741 Cleared_Total: 727
# aymkd37cilt2.pdf
# PDF: aymkd37cilt2.pdf Raw_Pages: 838 Cleared_Total: 832
# aymkd38cilt1.pdf
# PDF: aymkd38cilt1.pdf Raw_Pages: 454 Cleared_Total: 447
# aymkd38cilt2.pdf
# PDF: aymkd38cilt2.pdf Raw_Pages: 467 Cleared_Total: 449
# aymkd39cilt1.pdf
# PDF: aymkd39cilt1.pdf Raw_Pages: 576 Cleared_Total: 567
# aymkd39cilt2.pdf
# PDF: aymkd39cilt2.pdf Raw_Pages: 551 Cleared_Total: 539
# aymkd40cilt1.pdf
# PDF: aymkd40cilt1.pdf Raw_Pages: 452 Cleared_Total: 437
# aymkd40cilt2.pdf
# PDF: aymkd40cilt2.pdf Raw_Pages: 451 Cleared_Total: 443
# aymkd41.pdf
# PDF: aymkd41.pdf Raw_Pages: 576 Cleared_Total: 518
# aymkd42.pdf
# PDF: aymkd42.pdf Raw_Pages: 670 Cleared_Total: 626
# aymkd43.pdf
# PDF: aymkd43.pdf Raw_Pages: 654 Cleared_Total: 578
# aymkd44_1.pdf
# PDF: aymkd44_1.pdf Raw_Pages: 626 Cleared_Total: 595
# aymkd44_2.pdf
# PDF: aymkd44_2.pdf Raw_Pages: 624 Cleared_Total: 551
# aymkd46_1.pdf
# PDF: aymkd46_1.pdf Raw_Pages: 560 Cleared_Total: 522
# aymkd46_2.pdf
# PDF: aymkd46_2.pdf Raw_Pages: 600 Cleared_Total: 563
# aymkd46_3.pdf
# PDF: aymkd46_3.pdf Raw_Pages: 608 Cleared_Total: 544
# aymkd46_4.pdf
# PDF: aymkd46_4.pdf Raw_Pages: 577 Cleared_Total: 523
# kararlar_dergisi_45_1.pdf
# PDF: kararlar_dergisi_45_1.pdf Raw_Pages: 700 Cleared_Total: 673
# kararlar_dergisi_45_2.pdf
# PDF: kararlar_dergisi_45_2.pdf Raw_Pages: 694 Cleared_Total: 647
# kararlar_dergisi_45_3.pdf
# PDF: kararlar_dergisi_45_3.pdf Raw_Pages: 686 Cleared_Total: 584
# kararlar_dergisi_45_4.pdf
# PDF: kararlar_dergisi_45_4.pdf Raw_Pages: 616 Cleared_Total: 609
# kararlar_dergisi_45_5.pdf
# PDF: kararlar_dergisi_45_5.pdf Raw_Pages: 542 Cleared_Total: 507
# kararlar_dergisi_47_1.pdf
# PDF: kararlar_dergisi_47_1.pdf Raw_Pages: 640 Cleared_Total: 603
# kararlar_dergisi_47_2.pdf
# PDF: kararlar_dergisi_47_2.pdf Raw_Pages: 636 Cleared_Total: 597
# kararlar_dergisi_47_3.pdf
# PDF: kararlar_dergisi_47_3.pdf Raw_Pages: 677 Cleared_Total: 538
# kararlar_dergisi_48_1.pdf
# PDF: kararlar_dergisi_48_1.pdf Raw_Pages: 672 Cleared_Total: 635
# kararlar_dergisi_48_2.pdf
# PDF: kararlar_dergisi_48_2.pdf Raw_Pages: 686 Cleared_Total: 656
# kararlar_dergisi_48_3.pdf
# PDF: kararlar_dergisi_48_3.pdf Raw_Pages: 672 Cleared_Total: 638
# kararlar_dergisi_48_4.pdf
# PDF: kararlar_dergisi_48_4.pdf Raw_Pages: 661 Cleared_Total: 527
# kararlar_dergisi_49_1.pdf
# PDF: kararlar_dergisi_49_1.pdf Raw_Pages: 656 Cleared_Total: 611
# kararlar_dergisi_49_2.pdf
# PDF: kararlar_dergisi_49_2.pdf Raw_Pages: 660 Cleared_Total: 618
# kararlar_dergisi_49_3.pdf
# PDF: kararlar_dergisi_49_3.pdf Raw_Pages: 622 Cleared_Total: 527
# kararlar_dergisi_50_1.pdf
# PDF: kararlar_dergisi_50_1.pdf Raw_Pages: 791 Cleared_Total: 754
# kararlar_dergisi_50_2.pdf
# PDF: kararlar_dergisi_50_2.pdf Raw_Pages: 725 Cleared_Total: 696
# kararlar_dergisi_50_3.pdf
# PDF: kararlar_dergisi_50_3.pdf Raw_Pages: 763 Cleared_Total: 720
# kararlar_dergisi_50_4.pdf
# PDF: kararlar_dergisi_50_4.pdf Raw_Pages: 653 Cleared_Total: 622
# kararlar_dergisi_50_5.pdf
# PDF: kararlar_dergisi_50_5.pdf Raw_Pages: 785 Cleared_Total: 750
# kararlar_dergisi_50_6.pdf
# PDF: kararlar_dergisi_50_6.pdf Raw_Pages: 741 Cleared_Total: 715
# kararlar_dergisi_50_7.pdf
# PDF: kararlar_dergisi_50_7.pdf Raw_Pages: 725 Cleared_Total: 656
# kararlar_dergisi_50_8.pdf
# PDF: kararlar_dergisi_50_8.pdf Raw_Pages: 791 Cleared_Total: 753
# kararlar_dergisi_50_9.pdf
# PDF: kararlar_dergisi_50_9.pdf Raw_Pages: 821 Cleared_Total: 676
# kararlar_dergisi_51_1.pdf
# PDF: kararlar_dergisi_51_1.pdf Raw_Pages: 761 Cleared_Total: 732
# kararlar_dergisi_51_2.pdf
# PDF: kararlar_dergisi_51_2.pdf Raw_Pages: 749 Cleared_Total: 718
# kararlar_dergisi_51_3.pdf
# PDF: kararlar_dergisi_51_3.pdf Raw_Pages: 709 Cleared_Total: 661
# kararlar_dergisi_51_4.pdf
# PDF: kararlar_dergisi_51_4.pdf Raw_Pages: 607 Cleared_Total: 575
# kararlar_dergisi_51_5.pdf
# PDF: kararlar_dergisi_51_5.pdf Raw_Pages: 689 Cleared_Total: 640
# kararlar_dergisi_51_6.pdf
# PDF: kararlar_dergisi_51_6.pdf Raw_Pages: 657 Cleared_Total: 513
# kararlar_dergisi_52_1.pdf
# PDF: kararlar_dergisi_52_1.pdf Raw_Pages: 674 Cleared_Total: 643
# kararlar_dergisi_52_2.pdf
# PDF: kararlar_dergisi_52_2.pdf Raw_Pages: 708 Cleared_Total: 673
# kararlar_dergisi_52_3.pdf
# PDF: kararlar_dergisi_52_3.pdf Raw_Pages: 722 Cleared_Total: 686
# kararlar_dergisi_52_4.pdf
# PDF: kararlar_dergisi_52_4.pdf Raw_Pages: 711 Cleared_Total: 673
# kararlar_dergisi_52_5.pdf
# PDF: kararlar_dergisi_52_5.pdf Raw_Pages: 704 Cleared_Total: 678
# kararlar_dergisi_52_6.pdf
# PDF: kararlar_dergisi_52_6.pdf Raw_Pages: 738 Cleared_Total: 687
# kararlar_dergisi_52_7.pdf
# PDF: kararlar_dergisi_52_7.pdf Raw_Pages: 729 Cleared_Total: 596
# kararlar_dergisi_53_1.pdf
# PDF: kararlar_dergisi_53_1.pdf Raw_Pages: 609 Cleared_Total: 570
# kararlar_dergisi_53_2.pdf
# PDF: kararlar_dergisi_53_2.pdf Raw_Pages: 649 Cleared_Total: 589
# kararlar_dergisi_53_3.pdf
# PDF: kararlar_dergisi_53_3.pdf Raw_Pages: 585 Cleared_Total: 472
# kararlar_dergisi_54_1.pdf
# PDF: kararlar_dergisi_54_1.pdf Raw_Pages: 642 Cleared_Total: 596
# kararlar_dergisi_54_2.pdf
# PDF: kararlar_dergisi_54_2.pdf Raw_Pages: 632 Cleared_Total: 532
# kd_26.pdf
# PDF: kd_26.pdf Raw_Pages: 646 Cleared_Total: 622
# kd_27_1.pdf
# PDF: kd_27_1.pdf Raw_Pages: 472 Cleared_Total: 449
# kd_27_2.pdf
# PDF: kd_27_2.pdf Raw_Pages: 520 Cleared_Total: 493
# kd_28_1.pdf
# PDF: kd_28_1.pdf Raw_Pages: 428 Cleared_Total: 405
# kd_28_2.pdf
# PDF: kd_28_2.pdf Raw_Pages: 440 Cleared_Total: 404
# kd_29_1.pdf
# PDF: kd_29_1.pdf Raw_Pages: 614 Cleared_Total: 583
# kd_29_2.pdf
# PDF: kd_29_2.pdf Raw_Pages: 606 Cleared_Total: 579
# kd_30_1.pdf
# PDF: kd_30_1.pdf Raw_Pages: 634 Cleared_Total: 575
# kd_30_2.pdf
# PDF: kd_30_2.pdf Raw_Pages: 616 Cleared_Total: 582
# kd_31_1.pdf
# PDF: kd_31_1.pdf Raw_Pages: 514 Cleared_Total: 486
# kd_31_2.pdf
# PDF: kd_31_2.pdf Raw_Pages: 534 Cleared_Total: 499
# kd_32_1.pdf
# PDF: kd_32_1.pdf Raw_Pages: 528 Cleared_Total: 499
# kd_32_2.pdf
# PDF: kd_32_2.pdf Raw_Pages: 488 Cleared_Total: 450
# kd_33_1.pdf
# PDF: kd_33_1.pdf Raw_Pages: 448 Cleared_Total: 435
# kd_33_2.pdf
# PDF: kd_33_2.pdf Raw_Pages: 342 Cleared_Total: 317
# kd_34_1.pdf
# PDF: kd_34_1.pdf Raw_Pages: 586 Cleared_Total: 567
# kd_34_2.pdf
# PDF: kd_34_2.pdf Raw_Pages: 588 Cleared_Total: 565
# kd_35_1.pdf
# PDF: kd_35_1.pdf Raw_Pages: 364 Cleared_Total: 357
# kd_35_2.pdf
# PDF: kd_35_2.pdf Raw_Pages: 338 Cleared_Total: 326
# kd_55_1.pdf
# PDF: kd_55_1.pdf Raw_Pages: 750 Cleared_Total: 710
# kd_55_2.pdf
# PDF: kd_55_2.pdf Raw_Pages: 750 Cleared_Total: 702
# kd_55_3.pdf
# PDF: kd_55_3.pdf Raw_Pages: 762 Cleared_Total: 708
# kd_55_4.pdf
# PDF: kd_55_4.pdf Raw_Pages: 718 Cleared_Total: 600
# kd_56_01.pdf
# PDF: kd_56_01.pdf Raw_Pages: 732 Cleared_Total: 678
# kd_56_02.pdf
# PDF: kd_56_02.pdf Raw_Pages: 754 Cleared_Total: 628
# kd_57_01.pdf
# PDF: kd_57_01.pdf Raw_Pages: 647 Cleared_Total: 602
# kd_57_02.pdf
# PDF: kd_57_02.pdf Raw_Pages: 644 Cleared_Total: 613
# kd_57_03.pdf
# PDF: kd_57_03.pdf Raw_Pages: 718 Cleared_Total: 604
