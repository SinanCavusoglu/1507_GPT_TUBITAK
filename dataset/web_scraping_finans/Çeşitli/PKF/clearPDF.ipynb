# %% [markdown]
# ## [Extract Text](https://towardsdatascience.com/extracting-text-from-pdf-files-with-python-a-comprehensive-guide-9fc4003d517)
#
# ## [Language Detect](https://github.com/zafercavdar/fasttext-langdetect)

# %%
from io import StringIO

import os
import re
import PyPDF2
from pdfminer.high_level import extract_pages, extract_text
from pdfminer.layout import LTTextContainer, LTChar, LTRect, LTFigure, LAParams
from ftlangdetect import detect
import pycld2 as cld2

# %%
def collect_clear_text(text_list):
    text_list = [re.sub(r'\s+', ' ', text_.strip()).strip() for text_ in text_list]
    text = ' '.join(text_list)
    return text.strip()

def contents_references_rmv(text_per_page: dict,pages = 30, char_num = 1500, years_num = 6):
    def less_char_drop(text,char_num):
        if len(text) < char_num: return True
    def dot_drop(text):
        if (len(text) > char_num) and ((text.count(".") > 40) or (text.count("…")> 10) or (text.count("_")> 10) or (text.count("-")>10)) : return True
    def referencesYear_drop(text):
        year_list = list(range(1900,2025))
        year_count = 0
        for year in year_list:
            if str(year) in text:
                year_count += 1
        if year_count > years_num: return True
    total_pages = len(text_per_page)
    obs_numbers = list(range(0,pages)) + list(range(total_pages-pages,total_pages))
    for page_num in obs_numbers:
        page_word = f'Page_{page_num}'
        if page_num < pages:
            try:
                if (less_char_drop(text_per_page[page_word],char_num)) or (dot_drop(text_per_page[page_word]))  : del text_per_page[page_word]   
            except KeyError:
                continue
        else:
            if (less_char_drop(text_per_page[page_word],char_num)) or (referencesYear_drop(text_per_page[page_word]))  : del text_per_page[page_word]
    return text_per_page
    
def remove_eng(text_per_page: dict):
    dict_keys = list(text_per_page.keys())
    for keys in dict_keys: 
        text = text_per_page[keys]
        try:
            isReliable, textBytesFound, details = cld2.detect(text)
        except Exception as e:
            del text_per_page[keys]
            continue    
        lang = details[0][1]
        score = details[0][2]
        #print(keys, lang)
        if (lang == 'tr') and (score < 0.91):
            del text_per_page[keys]
        elif lang != "tr":
            del text_per_page[keys]
    return text_per_page

# %%
pdf_listDir = os.listdir("PKF_PDF")
for pdf in pdf_listDir:
    text_per_page = {}
    pdf_path = f'PKF_PDF/{pdf}'
    try:
        for pagenum, page in enumerate(extract_pages(pdf_path, laparams=LAParams(line_margin=2))):
            page_text = []
            page_elements = [(element.y1, element) for element in page._objs]
            page_elements.sort(key=lambda a: a[0], reverse=True)
            for i, component in enumerate(page_elements):
                element = component[1]
                if isinstance(element, LTTextContainer):
                    line_text = element.get_text()
                    page_text.append(line_text)
            dctkey = 'Page_' + str(pagenum)
            text_per_page[dctkey] = collect_clear_text(page_text)
    except TypeError as e:
        print(f"Error processing {pdf}: {e}")
        os.remove(pdf_path)
        continue
    except ValueError as e:
        print(f"Error processing {pdf}: {e}")
        os.remove(pdf_path)
        continue
    except Exception as e:
        print(f"Error {e}")
        os.remove(pdf_path)
        continue
    rawTotal = len(text_per_page)
    text_per_page = contents_references_rmv(text_per_page=text_per_page)
    text_per_page = remove_eng(text_per_page=text_per_page)
    """
    try:
        text_per_page = remove_eng(text_per_page=text_per_page)
    except Exception as e:
        print(f"Error in remove_eng for {pdf}: {e}")
        os.remove(pdf_path)
        continue
    """
    clearedTotal = len(text_per_page)
    if clearedTotal < 10:
        print("Bozuk pdf:", pdf)
    print("PDF:", pdf, "Raw_Pages:", rawTotal, "Cleared_Total:", clearedTotal)
    with open(f"PKF_TXT/{pdf.split('.')[0]}.txt" , 'w+', encoding="utf-8") as txt:
        for text in text_per_page.values():
            txt.write(text)
            txt.write('\n')
    os.rename( f"PKF_PDF/{pdf}", f"PKF_PDF_fin/finished_{pdf}")
# Out:
# Bozuk pdf: 1563280481.pdf
# PDF: 1563280481.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1563281963.pdf
# PDF: 1563281963.pdf Raw_Pages: 4 Cleared_Total: 0
# Bozuk pdf: 1563282162.pdf
# PDF: 1563282162.pdf Raw_Pages: 7 Cleared_Total: 1
# Bozuk pdf: 1563282201.pdf
# PDF: 1563282201.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1563283693.pdf
# PDF: 1563283693.pdf Raw_Pages: 7 Cleared_Total: 1
# Bozuk pdf: 1563283913.pdf
# PDF: 1563283913.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1563284102.pdf
# PDF: 1563284102.pdf Raw_Pages: 5 Cleared_Total: 1
# Bozuk pdf: 1563284844.pdf
# PDF: 1563284844.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1563285088.pdf
# PDF: 1563285088.pdf Raw_Pages: 5 Cleared_Total: 2
# Bozuk pdf: 1563287974.pdf
# PDF: 1563287974.pdf Raw_Pages: 3 Cleared_Total: 2
# Bozuk pdf: 1563288049.pdf
# PDF: 1563288049.pdf Raw_Pages: 6 Cleared_Total: 1
# Bozuk pdf: 1566308657.pdf
# PDF: 1566308657.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1566309162.pdf
# PDF: 1566309162.pdf Raw_Pages: 6 Cleared_Total: 2
# Bozuk pdf: 1566310765.pdf
# PDF: 1566310765.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1566311874.pdf
# PDF: 1566311874.pdf Raw_Pages: 6 Cleared_Total: 1
# Bozuk pdf: 1566384117.pdf
# PDF: 1566384117.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1566385500.pdf
# PDF: 1566385500.pdf Raw_Pages: 6 Cleared_Total: 0
# Bozuk pdf: 1566387183.pdf
# PDF: 1566387183.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1567065424.pdf
# PDF: 1567065424.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1568632845.pdf
# PDF: 1568632845.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1568633016.pdf
# PDF: 1568633016.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1568633148.pdf
# PDF: 1568633148.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1569244748.pdf
# PDF: 1569244748.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1569831240.pdf
# PDF: 1569831240.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1572441671.pdf
# PDF: 1572441671.pdf Raw_Pages: 3 Cleared_Total: 1
# Bozuk pdf: 1572442346.pdf
# PDF: 1572442346.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1572442860.pdf
# PDF: 1572442860.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1573819952.pdf
# PDF: 1573819952.pdf Raw_Pages: 3 Cleared_Total: 1
# Bozuk pdf: 1573820085.pdf
# PDF: 1573820085.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1576049103.pdf
# PDF: 1576049103.pdf Raw_Pages: 3 Cleared_Total: 1
# Bozuk pdf: 1576051315.pdf
# PDF: 1576051315.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1576052066.pdf
# PDF: 1576052066.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1577796663.pdf
# PDF: 1577796663.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1577796835.pdf
# PDF: 1577796835.pdf Raw_Pages: 3 Cleared_Total: 2
# Bozuk pdf: 1577796946.pdf
# PDF: 1577796946.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1577797090.pdf
# PDF: 1577797090.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1580819083.pdf
# PDF: 1580819083.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1580820049.pdf
# PDF: 1580820049.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1580821474.pdf
# PDF: 1580821474.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1581336199.pdf
# PDF: 1581336199.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1581928437.pdf
# PDF: 1581928437.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1583224446.pdf
# PDF: 1583224446.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1583224871.pdf
# PDF: 1583224871.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1595230094.pdf
# PDF: 1595230094.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1595230423.pdf
# PDF: 1595230423.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1595230637.pdf
# PDF: 1595230637.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1595230783.pdf
# PDF: 1595230783.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1595230979.pdf
# PDF: 1595230979.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1595231407.pdf
# PDF: 1595231407.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1595231574.pdf
# PDF: 1595231574.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1595231705.pdf
# PDF: 1595231705.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1595231728.pdf
# PDF: 1595231728.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1595231894.pdf
# PDF: 1595231894.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1595232046.pdf
# PDF: 1595232046.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1595250383.pdf
# PDF: 1595250383.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1595250554.pdf
# PDF: 1595250554.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1595250686.pdf
# PDF: 1595250686.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1595250822.pdf
# PDF: 1595250822.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1595250984.pdf
# PDF: 1595250984.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1595251134.pdf
# PDF: 1595251134.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1595251252.pdf
# PDF: 1595251252.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1595251497.pdf
# PDF: 1595251497.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1595251723.pdf
# PDF: 1595251723.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1595251969.pdf
# PDF: 1595251969.pdf Raw_Pages: 1 Cleared_Total: 0
# Error No /Root object! - Is this really a PDF?
# Bozuk pdf: 1596091716.pdf
# PDF: 1596091716.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1597388352.pdf
# PDF: 1597388352.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1599811325.pdf
# PDF: 1599811325.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1599811484.pdf
# PDF: 1599811484.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1599811651.pdf
# PDF: 1599811651.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1601631887.pdf
# PDF: 1601631887.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1601632002.pdf
# PDF: 1601632002.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1601632071.pdf
# PDF: 1601632071.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1601989623.pdf
# PDF: 1601989623.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1608196394.pdf
# PDF: 1608196394.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1608196492.pdf
# PDF: 1608196492.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1608196590.pdf
# PDF: 1608196590.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1608197827.pdf
# PDF: 1608197827.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1608198161.pdf
# PDF: 1608198161.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1608198441.pdf
# PDF: 1608198441.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1608198698.pdf
# PDF: 1608198698.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1608198895.pdf
# PDF: 1608198895.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1608199167.pdf
# PDF: 1608199167.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1608199519.pdf
# PDF: 1608199519.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1608199697.pdf
# PDF: 1608199697.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1608199698.pdf
# PDF: 1608199698.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1614064519.pdf
# PDF: 1614064519.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1614064593.pdf
# PDF: 1614064593.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1614064664.pdf
# PDF: 1614064664.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1614064755.pdf
# PDF: 1614064755.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1614064987.pdf
# PDF: 1614064987.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1614065053.pdf
# PDF: 1614065053.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1614065109.pdf
# PDF: 1614065109.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1614065554.pdf
# PDF: 1614065554.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1614066082.pdf
# PDF: 1614066082.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1614066177.pdf
# PDF: 1614066177.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1629183353.pdf
# PDF: 1629183353.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1629183472.pdf
# PDF: 1629183472.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1629183534.pdf
# PDF: 1629183534.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1629183606.pdf
# PDF: 1629183606.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1629183669.pdf
# PDF: 1629183669.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1633000023.pdf
# PDF: 1633000023.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1633000079.pdf
# PDF: 1633000079.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1633000153.pdf
# PDF: 1633000153.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1633000215.pdf
# PDF: 1633000215.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1633000282.pdf
# PDF: 1633000282.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1633000363.pdf
# PDF: 1633000363.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1633000447.pdf
# PDF: 1633000447.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1633000512.pdf
# PDF: 1633000512.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1633000586.pdf
# PDF: 1633000586.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1633000657.pdf
# PDF: 1633000657.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1633000711.pdf
# PDF: 1633000711.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1633000789.pdf
# PDF: 1633000789.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1633000873.pdf
# PDF: 1633000873.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1633000961.pdf
# PDF: 1633000961.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1633001024.pdf
# PDF: 1633001024.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1633001106.pdf
# PDF: 1633001106.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1633001240.pdf
# PDF: 1633001240.pdf Raw_Pages: 1 Cleared_Total: 0
# Error No /Root object! - Is this really a PDF?
# Bozuk pdf: 1633001421.pdf
# PDF: 1633001421.pdf Raw_Pages: 1 Cleared_Total: 0
# Error No /Root object! - Is this really a PDF?
# Bozuk pdf: 1633001603.pdf
# PDF: 1633001603.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1633001675.pdf
# PDF: 1633001675.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1636441158.pdf
# PDF: 1636441158.pdf Raw_Pages: 2 Cleared_Total: 0
# Error No /Root object! - Is this really a PDF?
# Bozuk pdf: 1636441297.pdf
# PDF: 1636441297.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1636441369.pdf
# PDF: 1636441369.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1636441436.pdf
# PDF: 1636441436.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1638363980.pdf
# PDF: 1638363980.pdf Raw_Pages: 3 Cleared_Total: 3
# Bozuk pdf: 1638365187.pdf
# PDF: 1638365187.pdf Raw_Pages: 3 Cleared_Total: 1
# Bozuk pdf: 1638365587.pdf
# PDF: 1638365587.pdf Raw_Pages: 3 Cleared_Total: 3
# Bozuk pdf: 1638365799.pdf
# PDF: 1638365799.pdf Raw_Pages: 3 Cleared_Total: 3
# Bozuk pdf: 1639479831.pdf
# PDF: 1639479831.pdf Raw_Pages: 3 Cleared_Total: 2
# Bozuk pdf: 1639480009.pdf
# PDF: 1639480009.pdf Raw_Pages: 3 Cleared_Total: 2
# Bozuk pdf: 1644478834.pdf
# PDF: 1644478834.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1644478907.pdf
# PDF: 1644478907.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1644479248.pdf
# PDF: 1644479248.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1644479410.pdf
# PDF: 1644479410.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1644479527.pdf
# PDF: 1644479527.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1644479645.pdf
# PDF: 1644479645.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1644479780.pdf
# PDF: 1644479780.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1645446411.pdf
# PDF: 1645446411.pdf Raw_Pages: 3 Cleared_Total: 2
# Bozuk pdf: 1645446698.pdf
# PDF: 1645446698.pdf Raw_Pages: 3 Cleared_Total: 2
# Bozuk pdf: 1652174202.pdf
# PDF: 1652174202.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1652174316.pdf
# PDF: 1652174316.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1652174369.pdf
# PDF: 1652174369.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1652174424.pdf
# PDF: 1652174424.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1652174495.pdf
# PDF: 1652174495.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1652174549.pdf
# PDF: 1652174549.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1652174619.pdf
# PDF: 1652174619.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1652174675.pdf
# PDF: 1652174675.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1652174726.pdf
# PDF: 1652174726.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1652174791.pdf
# PDF: 1652174791.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1652174880.pdf
# PDF: 1652174880.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1664804079.pdf
# PDF: 1664804079.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1664804270.pdf
# PDF: 1664804270.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1664804450.pdf
# PDF: 1664804450.pdf Raw_Pages: 3 Cleared_Total: 2
# Bozuk pdf: 1664804641.pdf
# PDF: 1664804641.pdf Raw_Pages: 3 Cleared_Total: 1
# Bozuk pdf: 1664804878.pdf
# PDF: 1664804878.pdf Raw_Pages: 3 Cleared_Total: 1
# Bozuk pdf: 1664805062.pdf
# PDF: 1664805062.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1664806163.pdf
# PDF: 1664806163.pdf Raw_Pages: 3 Cleared_Total: 2
# Bozuk pdf: 1664806337.pdf
# PDF: 1664806337.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1664806571.pdf
# PDF: 1664806571.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1678181511.pdf
# PDF: 1678181511.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678181623.pdf
# PDF: 1678181623.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1678181803.pdf
# PDF: 1678181803.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678181927.pdf
# PDF: 1678181927.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678182027.pdf
# PDF: 1678182027.pdf Raw_Pages: 4 Cleared_Total: 0
# Bozuk pdf: 1678182112.pdf
# PDF: 1678182112.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678182189.pdf
# PDF: 1678182189.pdf Raw_Pages: 2 Cleared_Total: 0
# Bozuk pdf: 1678182290.pdf
# PDF: 1678182290.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678182412.pdf
# PDF: 1678182412.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678182497.pdf
# PDF: 1678182497.pdf Raw_Pages: 2 Cleared_Total: 2
# Bozuk pdf: 1678182571.pdf
# PDF: 1678182571.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678182730.pdf
# PDF: 1678182730.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678182825.pdf
# PDF: 1678182825.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1678182980.pdf
# PDF: 1678182980.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678183063.pdf
# PDF: 1678183063.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678183249.pdf
# PDF: 1678183249.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678183331.pdf
# PDF: 1678183331.pdf Raw_Pages: 2 Cleared_Total: 1
# Bozuk pdf: 1678183412.pdf
# PDF: 1678183412.pdf Raw_Pages: 1 Cleared_Total: 1
# Bozuk pdf: 1678183908.pdf
# PDF: 1678183908.pdf Raw_Pages: 3 Cleared_Total: 2
# Bozuk pdf: 1678183997.pdf
# PDF: 1678183997.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678184083.pdf
# PDF: 1678184083.pdf Raw_Pages: 1 Cleared_Total: 0
# Bozuk pdf: 1678184329.pdf
# PDF: 1678184329.pdf Raw_Pages: 2 Cleared_Total: 0
